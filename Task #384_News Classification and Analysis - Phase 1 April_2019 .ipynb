# %%
#importing all the required libraries
import selenium
import pandas as pd
from selenium import webdriver # Importing selenium webdriver 

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")

# %%
# Opening the url
driver.get('https://timesofindia.indiatimes.com/archive/year-2019,month-4.cms')

# %%
#creating empty lists
Date=[]
Author=[]
Vertical=[]
Headline=[]
Description=[]

# %%
#creating a list url so that all the urls of date from 1st April to 30th April can be appended
url=[]
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[2]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[3]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[4]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[5]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[6]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[7]/a"):
    url.append(i.get_attribute("href"))    
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[3]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[4]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[5]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[1]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[2]/a"):
    url.append(i.get_attribute("href"))  
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[3]/a"):
    url.append(i.get_attribute("href"))

# %%
url
# Out:
# ['https://timesofindia.indiatimes.com/2019/4/1/archivelist/year-2019,month-4,starttime-43556.cms',
#  'https://timesofindia.indiatimes.com/2019/4/2/archivelist/year-2019,month-4,starttime-43557.cms',
#  'https://timesofindia.indiatimes.com/2019/4/3/archivelist/year-2019,month-4,starttime-43558.cms',
#  'https://timesofindia.indiatimes.com/2019/4/4/archivelist/year-2019,month-4,starttime-43559.cms',
#  'https://timesofindia.indiatimes.com/2019/4/5/archivelist/year-2019,month-4,starttime-43560.cms',
#  'https://timesofindia.indiatimes.com/2019/4/6/archivelist/year-2019,month-4,starttime-43561.cms',
#  'https://timesofindia.indiatimes.com/2019/4/7/archivelist/year-2019,month-4,starttime-43562.cms',
#  'https://timesofindia.indiatimes.com/2019/4/8/archivelist/year-2019,month-4,starttime-43563.cms',
#  'https://timesofindia.indiatimes.com/2019/4/9/archivelist/year-2019,month-4,starttime-43564.cms',
#  'https://timesofindia.indiatimes.com/2019/4/10/archivelist/year-2019,month-4,starttime-43565.cms',
#  'https://timesofindia.indiatimes.com/2019/4/11/archivelist/year-2019,month-4,starttime-43566.cms',
#  'https://timesofindia.indiatimes.com/2019/4/12/archivelist/year-2019,month-4,starttime-43567.cms',
#  'https://timesofindia.indiatimes.com/2019/4/13/archivelist/year-2019,month-4,starttime-43568.cms',
#  'https://timesofindia.indiatimes.com/2019/4/14/archivelist/year-2019,month-4,starttime-43569.cms',
#  'https://timesofindia.indiatimes.com/2019/4/15/archivelist/year-2019,month-4,starttime-43570.cms',
#  'https://timesofindia.indiatimes.com/2019/4/16/archivelist/year-2019,month-4,starttime-43571.cms',
#  'https://timesofindia.indiatimes.com/2019/4/17/archivelist/year-2019,month-4,starttime-43572.cms',
#  'https://timesofindia.indiatimes.com/2019/4/18/archivelist/year-2019,month-4,starttime-43573.cms',
#  'https://timesofindia.indiatimes.com/2019/4/19/archivelist/year-2019,month-4,starttime-43574.cms',
#  'https://timesofindia.indiatimes.com/2019/4/20/archivelist/year-2019,month-4,starttime-43575.cms',
#  'https://timesofindia.indiatimes.com/2019/4/21/archivelist/year-2019,month-4,starttime-43576.cms',
#  'https://timesofindia.indiatimes.com/2019/4/22/archivelist/year-2019,month-4,starttime-43577.cms',
#  'https://timesofindia.indiatimes.com/2019/4/23/archivelist/year-2019,month-4,starttime-43578.cms',
#  'https://timesofindia.indiatimes.com/2019/4/24/archivelist/year-2019,month-4,starttime-43579.cms',
#  'https://timesofindia.indiatimes.com/2019/4/25/archivelist/year-2019,month-4,starttime-43580.cms',
#  'https://timesofindia.indiatimes.com/2019/4/26/archivelist/year-2019,month-4,starttime-43581.cms',
#  'https://timesofindia.indiatimes.com/2019/4/27/archivelist/year-2019,month-4,starttime-43582.cms',
#  'https://timesofindia.indiatimes.com/2019/4/28/archivelist/year-2019,month-4,starttime-43583.cms',
#  'https://timesofindia.indiatimes.com/2019/4/29/archivelist/year-2019,month-4,starttime-43584.cms',
#  'https://timesofindia.indiatimes.com/2019/4/30/archivelist/year-2019,month-4,starttime-43585.cms']

# %%
#opening the first url i.e., 1st April
driver.get(url[0])
URLS1=[] #appending all the urls of the news from 1st April
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS1.append(i.get_attribute("href"))

# %%
for i in URLS1[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[1])
URLS2=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS2.append(i.get_attribute("href"))

# %%
for i in URLS2[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[2])
URLS3=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS3.append(i.get_attribute("href"))

# %%
for i in URLS3[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[3])
URLS4=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS4.append(i.get_attribute("href"))

# %%
for i in URLS4[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[4])
URLS5=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS5.append(i.get_attribute("href"))

# %%
for i in URLS5[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[5])
URLS6=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS6.append(i.get_attribute("href"))

# %%
for i in URLS6[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[6])
URLS7=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS7.append(i.get_attribute("href"))

# %%
for i in URLS7[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[7])
URLS8=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS8.append(i.get_attribute("href"))

# %%
for i in URLS8[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[8])
URLS9=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS9.append(i.get_attribute("href"))

# %%
for i in URLS9[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[9])
URLS10=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS10.append(i.get_attribute("href"))

# %%
for i in URLS10[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[10])
URLS11=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS11.append(i.get_attribute("href"))

# %%
for i in URLS11[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[11])
URLS12=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS12.append(i.get_attribute("href"))

# %%
for i in URLS12[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[12])
URLS13=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS13.append(i.get_attribute("href"))

# %%
for i in URLS13[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[13])
URLS14=[]
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS14.append(i.get_attribute("href"))

# %%
for i in URLS14[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[14])
URLS15=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS15.append(i.get_attribute("href"))

# %%
for i in URLS15[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[15])
URLS16=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS16.append(i.get_attribute("href"))

# %%
for i in URLS16[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[16])
URLS17=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS17.append(i.get_attribute("href"))

# %%
for i in URLS17[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[17])
URLS18=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS18.append(i.get_attribute("href"))

# %%
for i in URLS18[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[18])
URLS19=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS19.append(i.get_attribute("href"))

# %%
for i in URLS19[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[19])
URLS20=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS20.append(i.get_attribute("href"))

# %%
for i in URLS20[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[20])
URLS21=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS21.append(i.get_attribute("href"))

# %%
for i in URLS21[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[21])
URLS22=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS22.append(i.get_attribute("href"))

# %%
for i in URLS22[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[22])
URLS23=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS23.append(i.get_attribute("href"))

# %%
for i in URLS23[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[23])
URLS24=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS24.append(i.get_attribute("href"))

# %%
for i in URLS24[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[24])
URLS25=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS25.append(i.get_attribute("href"))

# %%
for i in URLS25[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[25])
URLS26=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS26.append(i.get_attribute("href"))

# %%
for i in URLS26[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[26])
URLS27=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS27.append(i.get_attribute("href"))

# %%
for i in URLS27[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[27])
URLS28=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS28.append(i.get_attribute("href"))

# %%
for i in URLS28[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[28])
URLS29=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS29.append(i.get_attribute("href"))

# %%
for i in URLS29[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[29])
URLS30=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS30.append(i.get_attribute("href"))

# %%
for i in URLS30[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
print(len(Date),len(Description),len(Headline),len(Vertical),len(Author))
# Out:
# 600 600 600 600 600

# %%
#creating a dataframe
import pandas as pd
News=pd.DataFrame({})
News['Date']=Date
News['Author']=Author
News['Vertical']=Vertical
News['Headline']=Headline
News['Description']=Description
News
# Out:
#                                                   Date           Author  \
# 0                         TNN | Apr 1, 2019, 00:00 IST                -
# 1    Reema Gowalla | TNN | Updated: Apr 16, 2019, 1...    Reema Gowalla
# 2                                                    -     Vinay Lokesh
# 3                     Updated: Apr 16, 2019, 11:29 IST    Reema Gowalla
# 4                      Created: Apr 1, 2019, 00:00 IST        V Lakshmi
# ..                                                 ...              ...
# 595       Dipak K Dash | TNN | Apr 30, 2019, 00:44 IST     Dipak K Dash
# 596                                                  -                -
# 597                   Created: Apr 30, 2019, 01:00 IST    Tanvi Trivedi
# 598                   Created: Apr 30, 2019, 01:00 IST    Tanvi Trivedi
# 599                   Created: Apr 30, 2019, 01:00 IST  Soumya Vajpayee
#
#           Vertical                                           Headline  \
# 0             City  The book launch of ace batsman Alvin Kallichar...
# 1             City                         Theatre review: Algorithms
# 2               TV                                                  -
# 3    Entertainment                         Theatre review: Algorithms
# 4                -  ‘I’m learning Tamil and I take it seriously be...
# ..             ...                                                ...
# 595          India  Only colour of school buses has changed, not t...
# 596              -                                                  -
# 597             TV  Deepika Singh: My husband Rohit has decided to...
# 598  Entertainment  Behzad Khambata: It is tough to make a film an...
# 599              -  ‘Jazz brings a distinct colour to Bollywood mu...
#
#                                            Description
# 0    For the guests gathered at this do, it was muc...
# 1    Playwright and director:\nChanakya Vyas\nLangu...
# 2                                                    -
# 3    Playwright and director: Chanakya Vyas Languag...
# 4    The picture that Raashi Khanna posted recently...
# ..                                                 ...
# 595  NEW DELHI: School buses have only changed colo...
# 596                                                  -
# 597  Actress Deepika Singh, who was last seen on 'D...
# 598  It took Behzad Khambata, who has assisted on f...
# 599  Say jazz, and the thought that comes to mind i...
#
# [600 rows x 5 columns]

# %%
#Saving our dataframe into csv file
News.to_csv('April_News_2019.csv', index = False)
